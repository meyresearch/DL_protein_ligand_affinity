# %%
import sys,os
import random
import numpy as np
import json
from collections import OrderedDict
from gnn import GNNNet
from utils import *
from emetrics import *
from data_process import create_dataset_for_5folds
import torch
import torch.nn as nn
from torch_geometric.data import DataLoader
import rdkit as rd
from torch_sparse import SparseTensor,transpose
import deepchem
import tensorflow as tf
import pandas as pd
import pickle
import matplotlib.pyplot as plt
# Out:
# /rds/user/co-gora1/hpc-work/DGraphDTA/emetrics.py:27: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if pair is not 0:
# RDKit WARNING: [22:18:46] Enabling RDKit 2019.09.3 jupyter extensions
# [22:18:46] Enabling RDKit 2019.09.3 jupyter extensions

# %%
ep=[i for i in range(1,501)]

# %%
my_file = open("mse_alpha_500_file.txt", "r")
content = my_file.read()
content=content.splitlines()
content=[float(i) for i in content]

# %%
mse_list_pconcs4=content

# %%
mse_list_esm1=content

# %%
mse_list_alpha=content

# %%
mse_list_esm2=content

# %%
mse_list_esm3=content

# %%
plt.xlabel("#Epochs")
plt.ylabel("MSE")
plt.title("Error Curves- 187 proteins KIBA dataset")
plt.plot(ep,mse_list_esm1,label="ESM-1st run")
plt.plot(ep,mse_list_esm2,label="ESM-2nd run")
plt.plot(ep,mse_list_esm3,label="ESM-3rd run")
plt.legend()

# %%
ep=[i for i in range(1,501)]
plt.xlabel("#Epochs")
plt.ylabel("MSE")
plt.title("Error Curves- 187 proteins KIBA dataset")
plt.plot(ep,mse_list_esm1,label="ESM")
plt.plot(ep,mse_list_pconcs4,label="Pconsc4")
plt.plot(ep,mse_list_alpha,label="AlphaFold2")
plt.legend()

# %%
import seaborn as sns

# %%
sns.lineplot(ep,mse_list_alpha)
# Out:
# /disk/scratch/miniconda3/envs/mldd1/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
from tdc.multi_pred import DTI
data = DTI(name = 'KIBA')
split = data.get_split()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from tdc.multi_pred import DTI
#       2 data = DTI(name = 'KIBA')
#       3 split = data.get_split()
#
# ModuleNotFoundError: No module named 'tdc'
